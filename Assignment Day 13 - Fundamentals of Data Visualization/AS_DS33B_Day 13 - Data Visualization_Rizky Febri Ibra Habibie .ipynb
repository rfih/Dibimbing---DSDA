# %% [markdown]
# ---
# # **INTRUKSI PENGERJAAN**
# 1.   Save file `.ipynb` ini dan copy pada Google Drive Anda. Anda dapat melakukannya dengan cara berikut:
#
#       - Klik menu `file` dan pilih `Save a copy in drive`
#
#
# 2.   Isi identitas Anda terlebih dahulu pada bagian identitas. Anda dapat melakukannya dengan cara berikut:
#
#       - Klik 2x pada bagian `nama`. Jika sudah selesai mengisi, tekan `shift+enter`
#
#
# 3. Anda bisa mendownload data yang digunakan pada link berikut:
#
#     - https://drive.google.com/file/d/1Wv1J4vQxbJ4Jyla8fkem-DZTC2SeDgbo/view?usp=sharing
#
#
# 4. Bacalah soal-soal yang ada pada file ipynb dengan teliti. Jika ada pertanyaan terkait soal, silahkan tanya ke mentor Anda
#
#
# 5. _Library_ yang digunakan untuk visualisasi terbatas pada `matplotlib` dan/atau `seaborn`. Anda dipersilahkan menggunakan library lain `hanya untuk` membantu melengkapi atribut data visualisasi
#
#
# 6. Anda dapat membaca `Data Description` untuk mendapatkan penjelasan mengenai kolom-kolom yang ada pada dataset
#
#
# 7. Berikan `comment` atau `text` pada code Anda yang menjelaskan jawaban tersebut menjawab soal nomor berapa
#
#
# 8. Anda dipersilahkan membuat visualisasi dengan kreatifitas Anda yang dapat membantu pembaca memahami visualisasi lebih mudah
# ---

# %% [markdown]
# # **Identitas Diri**
#
# Nama  : Rizky Febri Ibra Habibie
#
# Kelas : DS Batch 33B

# %% [markdown]
# # **Data Description**

# %% [markdown]
# ```
# ABOUT DATA
# ----------
# A fictional telco company that provided home phone and Internet services to 7043 customers in California in Q3.
#
# COLUMNS EXPLANATION
# -------------------
# CustomerID: A unique ID that identifies each customer.
#
# Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# Country: The country of the customer’s primary residence.
#
# State: The state of the customer’s primary residence.
#
# City: The city of the customer’s primary residence.
#
# Zip Code: The zip code of the customer’s primary residence.
#
# Lat Long: The combined latitude and longitude of the customer’s primary residence.
#
# Latitude: The latitude of the customer’s primary residence.
#
# Longitude: The longitude of the customer’s primary residence.
#
# Gender: The customer’s gender: Male, Female
#
# Senior Citizen: Indicates if the customer is 65 or older: Yes, No
#
# Partner: Indicate if the customer has a partner: Yes, No
#
# Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
# Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
# Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
#
# Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
# Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
# Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
# Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
# Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
# Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
# Streaming TV: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
# Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
#
# Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
# Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
#
# Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
# Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
#
# Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
# Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
# CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
# Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category.
# ```

# %% [markdown]
# # **Soal Assignment**
#
# 1.   Buatlah visualiasi untuk menemukan perbedaan persentase dari `customer yang churn` dan `customer yang tidak churn`
# 2.   Buatlah visualisasi untuk melihat hubungan antara `jumlah bulan yang telah dihabiskan customer` di perusahaan pada akhir kuartal dan `total tagihan customer`
# 3.   Buatlah visualisasi untuk melihat 5 `kota` teratas yang customernya melakukan churn dan tidak melakukan churn
# 4.   Buatlah visualisasi untuk melihat persebaran data dari `tenure months` untuk masing-masing `churn label`
# 5.   Jelaskan insight dan saran action yang Anda dapatkan pada setiap visualisasi

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.datasets import load_iris, load_wine, load_diabetes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
churn_df = pd.read_csv("/Users/hbb/Document/Dibimbing---DSDA/Assignment Day 13 - Fundamentals of Data Visualization/Telco_customer_churn.csv")
churn_df.sample(5)
# Out:
#       CustomerID  Count        Country       State           City  Zip Code  \
# 352   3838-OZURD      1  United States  California      Somes Bar     95568
# 3689  7706-YLMQA      1  United States  California         Madera     93638
# 4838  4098-NAUKP      1  United States  California         Oceano     93445
# 2148  7156-MXBJE      1  United States  California      San Diego     92127
# 3402  6661-EIPZC      1  United States  California  Grand Terrace     92313
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 352   41.444606, -123.471895  41.444606 -123.471895    Male  ...
# 3689  37.004068, -119.930027  37.004068 -119.930027  Female  ...
# 4838  35.059695, -120.604741  35.059695 -120.604741    Male  ...
# 2148  33.017518, -117.118456  33.017518 -117.118456  Female  ...
# 3402  34.029175, -117.307211  34.029175 -117.307211  Female  ...
#
#             Contract Paperless Billing             Payment Method  \
# ...

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
churn_df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %% [markdown]
# ## 1. Buatlah visualiasi untuk menemukan perbedaan persentase dari customer yang churn dan customer yang tidak churn

# %%
#Piechart (Churn Label & Churn Value)
plt.figure(figsize=(10,6))
plt.pie(churn_df['Churn Label'].value_counts(), labels=['No','Yes'], autopct='%1.1f%%')
plt.title('Churn Label')

plt.figure(figsize=(10,6))
plt.pie(churn_df['Churn Value'].value_counts(), labels=['0','1'], autopct='%1.1f%%')
plt.title('Churn Value')
# Out:
# Text(0.5, 1.0, 'Churn Value')

# %% [markdown]
# Insight:
# - Perbedaan customer yang churn dan tidak churn dapat dilihat dari kolom 'Churn Label' dan atau "Churn Value".
# - Untuk memastikan, saya membuat dua pie chart dari dua kolom tersebut untuk membuktikan bahwa valuenya sama.
# - Customer yang melakukan Churn sebesar 26.5%.
# - Customer yang tidak Churn sebesar 73.5%.

# %% [markdown]
# ## 2. Buatlah visualisasi untuk melihat hubungan antara jumlah bulan yang telah dihabiskan customer di perusahaan pada akhir kuartal dan total tagihan customer

# %%
#tenure months vs total charges
plt.figure(figsize=(10,6))
sns.scatterplot(x='Tenure Months', y='Total Charges', data=churn_df)
plt.title('Tenure Months vs Total Charges')
# Out:
# Text(0.5, 1.0, 'Tenure Months vs Total Charges')

# %%
data_month = churn_df[['Tenure Months', 'Total Charges']]

# %%
data_month
# Out:
#       Tenure Months Total Charges
# 0                 2        108.15
# 1                 2        151.65
# 2                 8         820.5
# 3                28       3046.05
# 4                49        5036.3
# ...             ...           ...
# 7038             72        1419.4
# 7039             24        1990.5
# 7040             72        7362.9
# 7041             11        346.45
# 7042             66        6844.5
#
# [7043 rows x 2 columns]

# %%
check = data_month[data_month["Tenure Months"] == 2]
check
# Out:
#       Tenure Months Total Charges
# 0                 2        108.15
# 1                 2        151.65
# 14                2        144.15
# 32                2         81.25
# 40                2         242.8
# ...             ...           ...
# 6751              2          39.8
# 6775              2          85.1
# 6905              2         147.8
# 6910              2          32.7
# 7033              2         39.25
#
# [238 rows x 2 columns]

# %%
data_monthly = data_month.groupby('Tenure Months').count()
data_monthly
# Out:
#                Total Charges
# Tenure Months
# 0                         11
# 1                        613
# 2                        238
# 3                        200
# 4                        176
# ...                      ...
# 68                       100
# 69                        95
# 70                       119
# 71                       170
# 72                       362
#
# [73 rows x 1 columns]

# %%
plt.figure(figsize=(10,6))
sns.set(style="whitegrid")
sns.lineplot(data=data_monthly, x='Tenure Months', y='Total Charges')
plt.title('Total Charges by Months')
plt.xlabel('Months')
plt.ylabel('Total Charges')
plt.show()

# %% [markdown]
# Insight:
# - Jumlah bulan yang dihabiskan oleh customer di perusahaan pada akhir quartal dengan total tagihan customer memiliki angka yang cukup tinggi pada bulan ke 2-3 dan 72-73

# %% [markdown]
# ## 3. Buatlah visualisasi untuk melihat 5 kota teratas yang customernya melakukan churn dan tidak melakukan churn

# %%
city_churn_counts = churn_df.groupby(['City', 'Churn Label']).size().reset_index(name='Count')
city_churn_counts
# Out:
#               City Churn Label  Count
# 0           Acampo          No      1
# 1           Acampo         Yes      3
# 2            Acton          No      4
# 3         Adelanto          No      4
# 4         Adelanto         Yes      1
# ...            ...         ...    ...
# 1945       Yucaipa          No      3
# 1946       Yucaipa         Yes      1
# 1947  Yucca Valley          No      5
# 1948         Zenia          No      3
# 1949         Zenia         Yes      1
#
# [1950 rows x 3 columns]

# %%
churned = city_churn_counts[city_churn_counts['Churn Label'] == 'Yes'].nlargest(5, 'Count')
not_churned = city_churn_counts[city_churn_counts['Churn Label'] == 'No'].nlargest(5, 'Count')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=churned, x='City', y='Count', palette='Reds_r')
plt.title('Top 5 Kota dengan Churn Tertinggi')
plt.xlabel('Kota')
plt.ylabel('Jumlah Customer')

plt.figure(figsize=(10,6))
sns.barplot(data=not_churned, x='City', y='Count', palette='Blues_r')
plt.title('Top 5 Kota dengan Tidak Churn Tertinggi')
plt.xlabel('Kota')
plt.ylabel('Jumlah Customer')
# Out:
# <ipython-input-61-9ec083032a43>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=churned, x='City', y='Count', palette='Reds_r')
# <ipython-input-61-9ec083032a43>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=not_churned, x='City', y='Count', palette='Blues_r')
# Text(0, 0.5, 'Jumlah Customer')

# %% [markdown]
# Insight:
# - Churn dan non-Churn tertinggi dimiliki oleh kota Los Angeles.
# - Sedangkan Churn terendah ada di Sacramento.
# - non-Churn terendah ada di San Fransisco.

# %% [markdown]
# ## 4. Buatlah visualisasi untuk melihat persebaran data dari tenure months untuk masing-masing churn label

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=churn_df, x='Churn Label', y='Tenure Months', palette='Set2')
plt.title('Persebaran Tenure Months Berdasarkan Churn Label')
plt.xlabel('Churn Label')
plt.ylabel('Jumlah Bulan (Tenure)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-67-48f4d2cabb7e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=churn_df, x='Churn Label', y='Tenure Months', palette='Set2')

# %% [markdown]
# Insight:
# - Customer yang churn ("Yes") umumnya memiliki tenure lebih pendek yang banyak churn terjadi di bulan-bulan awal.
# - Customer yang tidak churn ("No") memiliki tenure lebih panjang yang menunjukkan loyalitas atau kepuasan lebih tinggi.
# - Terdapat beberapa outlier di kedua kelompok, terutama di kelompok churn yang menunjukkan pelanggan lama dengan masa langganan sangat panjang.

# %% [markdown]
# ## 5. Jelaskan insight dan saran action yang Anda dapatkan pada setiap visualisasi

# %% [markdown]
# 1. Persentase Customer yang Churn dan Tidak Churn
# Dari pie chart Churn Label dan Churn Value, terlihat bahwa: 26.5% pelanggan telah melakukan churn (berhenti langganan). 73.5% pelanggan masih aktif (tidak churn). Kedua kolom tersebut memberikan informasi yang sama dalam bentuk label dan nilai numerik.
#
# 2. Hubungan Jumlah Bulan (Tenure) dan Total Tagihan
# Visualisasi scatter plot menunjukkan bahwa semakin lama pelanggan berlangganan (tenure), maka total tagihan cenderung meningkat.
# Analisis berdasarkan jumlah customer per bulan (line chart) menunjukkan jumlah pelanggan tinggi di bulan 2–3 dan 72–73, yang mungkin merupakan fase awal dan akhir kontrak.
# Hal ini menandakan dua titik penting: churn awal dan loyal customer jangka panjang.
#
# 3. 5 Kota Teratas Berdasarkan Status Churn
# Los Angeles muncul sebagai kota dengan jumlah churn dan non-churn tertinggi, menunjukkan tingginya volume pelanggan di kota ini.
# Kota dengan churn terendah di top 5 adalah Sacramento, sedangkan untuk non-churn adalah San Francisco.
# Ini menunjukkan konsentrasi pelanggan dan potensi target untuk strategi retensi atau ekspansi.
#
# 4. Persebaran Tenure Berdasarkan Status Churn
# Customer yang churn biasanya memiliki tenure pendek. Artinya, banyak pelanggan berhenti langganan di awal masa berlangganan.
# Customer yang tidak churn memiliki masa langganan yang lebih panjang, menunjukkan kepuasan dan loyalitas yang lebih tinggi.
# Outlier menunjukkan bahwa ada pelanggan lama yang tetap churn — bisa jadi karena faktor lain seperti harga atau kompetitor.

# %% [markdown]
# Insight Umum:
# - Mayoritas pelanggan tidak churn, tetapi churn tetap signifikan (26.5%) dan terjadi lebih awal.
# - Perusahaan dapat menargetkan program retensi lebih agresif di 3 bulan pertama.
# - Kota-kota besar seperti Los Angeles merupakan pusat aktivitas pelanggan dan bisa menjadi fokus strategi pemasaran.
# - Informasi tenure sangat berguna dalam mengidentifikasi pelanggan berisiko churn lebih awal.
