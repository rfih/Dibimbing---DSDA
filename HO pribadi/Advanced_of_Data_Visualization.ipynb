# %% [markdown]
# ## Day 13 - Fundamentals Data Visualization
# ### Basic Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris, load_wine, load_diabetes

# Set styling for plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set(style="whitegrid")

# Load data
data = load_iris()
data_df = pd.DataFrame(data.data, columns=data.feature_names)
data_df['species'] = pd.Categorical.from_codes(data.target, data.target_names)
data_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
### Scatter Plot
plt.figure(figsize=(10,6))
plt.scatter(data_df['sepal length (cm)'], data_df['sepal width (cm)'])
plt.title('Sepal Length vs Sepal Width (CM)')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
### Seaborn Enhanced Scatter Plot
plt.figure(figsize=(12,8))
sns.scatterplot(
    data = data_df,
    x = 'sepal length (cm)',
    y = 'sepal width (cm)',
    hue = 'species',
    palette = 'viridis'
)

plt.title('Sepal Dimensions by Species', fontsize=15)
plt.xlabel('Sepal Length (cm)', fontsize=12)
plt.ylabel('Sepal Width (cm)', fontsize = 12)
plt.legend(title='species', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(
    data=data_df,
    x='petal length (cm)',
    y='petal width (cm)',
    hue='species',
    palette = 'cubehelix',
    alpha = 1
)

plt.title('Petal Dimension by Species', fontsize =15)
plt.xlabel('Petal length', fontsize = 15)
plt.ylabel('Petal width', fontsize = 15)
plt.legend(title = 'species', fontsize = 15)
plt.show()

# %% [markdown]
# ### Spotify Visualization

# %%
data = pd.read_csv('spotify_dataset.csv')
data
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              2000 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
# ...

# %%
data.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667438     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512434     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
### Popularity Distribution
plt.figure(figsize=(12,10))
sns.histplot(data = data, x='popularity', kde=True)
plt.title('Popularity by Distribution')
plt.xlabel('Popularity')
plt.ylabel('Count')
plt.show()

# %%
data['popularity'].describe()
# Out:
# count    2000.000000
# mean       59.872500
# std        21.335577
# min         0.000000
# 25%        56.000000
# 50%        65.500000
# 75%        73.000000
# max        89.000000
# Name: popularity, dtype: float64

# %% [markdown]
# ### Insight :
# 1. mean < median < modus (left skew)
# 2. Distribusi popularity berada di rentang angka 40-80
# 3. Terdapat nilai popularity 0 sekitar 175
# 4. Modus pada popularity berada di nilai 70

# %%
## Line Chart (Hitung total lagu berdasarkan tahun)
plt.figure(figsize=(10,8))
sns.lineplot(data=data, x='year', y='song')
plt.title('Total Song by Year')
plt.xlabel('Year')
plt.ylabel('Total Song')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
# ...

# %%
data_year = data[['year', 'song']]
data_year
# Out:
#       year                                    song
# 0     2000                  Oops!...I Did It Again
# 1     1999                    All The Small Things
# 2     1999                                 Breathe
# 3     2000                            It's My Life
# 4     2000                             Bye Bye Bye
# ...    ...                                     ...
# 1995  2019                                  Sucker
# 1996  2019                            Cruel Summer
# 1997  2019                              The Git Up
# 1998  2019  Dancing With A Stranger (with Normani)
# 1999  2019                                 Circles
#
# [2000 rows x 2 columns]

# %%
data_yearly = data_year.groupby('year').count()
data_yearly
# Out:
#       song
# year
# 1998     1
# 1999    38
# 2000    74
# 2001   108
# 2002    90
# 2003    97
# 2004    96
# 2005   104
# 2006    95
# 2007    94
# 2008    97
# 2009    84
# 2010   107
# 2011    99
# 2012   115
# 2013    89
# 2014   104
# 2015    99
# 2016    99
# 2017   111
# 2018   107
# 2019    89
# 2020     3

# %%
## Line chart total song per year
plt.figure(figsize=(10,8))
sns.lineplot(data=data_yearly, x='year', y='song')
plt.title('Total Song by Year')
plt.xlabel('Year')
plt.ylabel('Total Song')
# Out:
# Text(0, 0.5, 'Total Song')

# %% [markdown]
# ### Insight :
# 1. 2001 hingga 2018 jumlah lagu berada di posisi yang stabil yang berada di angka 85-115
# 2. Ditahun 2012 merupakan tahun tertinggi pada saat release lagu di spotify

# %%
### Bar chart (Perhitungan lagu tiap genre)
data_genre = data.groupby('genre', as_index=False).count().sort_values(by='song', ascending=False)
data_genre_top10 = data_genre.head(10)

plt.figure(figsize=(10,8))
sns.barplot(data=data_genre_top10, x='genre', y='song')
plt.title('Top 10 Song by Genre')
plt.xlabel('Genre')
plt.xticks(rotation=90)
plt.ylabel('Total Song')
plt.show()

# %% [markdown]
# ### Insight :
# 1. Lagu pop yang paling banyak diminati, disusul dengan lagu hip hop
# 2. Genre Dance/electronic kurang diminati

# %%
### Pie Chart (Explicit distribution)
explicit_data = data.groupby('explicit', as_index=False).count()

plt.figure(figsize=(10,8))
plt.pie(explicit_data['song'], labels=explicit_data['explicit'], autopct='%1.1f%%')
plt.title('Explicit Distribution')
plt.show()

# %% [markdown]
# ### Insight :
# 1. Lirik lagu atau video musik yang mengandung satu atau lebih kriteria yang dapat menyinggung  atau tidak cocok untuk anak-anak lebih sedikit dengan porsi 27,5%

# %%
### Scatter Plot (Duration and Year)
plt.figure(figsize=(12,10))
sns.scatterplot(data=data, x='year', y='duration_ms')
plt.title('Duration vs Year')
plt.xlabel('Year')
plt.ylabel('Duration (ms)')
plt.show()

# %%
### Correlation between duration and year
data[['duration_ms', 'year']].corr()
# Out:
#              duration_ms      year
# duration_ms     1.000000 -0.316534
# year           -0.316534  1.000000

# %% [markdown]
# ### Insight : Semakin bertambah tahun, maka durasi lagu semakin berkurang (weak negatif correlation)

# %% [markdown]
# ## Day 14 - Advanced Data Visualization

# %%
data
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
### Correlation
numeric_columns = data.select_dtypes(include=['number']).columns
numeric_columns
# Out:
# Index(['duration_ms', 'year', 'popularity', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
corr_matrix = data[numeric_columns].corr()
corr_matrix
# Out:
#                   duration_ms      year  popularity  danceability    energy  \
# duration_ms          1.000000 -0.316534    0.050617     -0.060057 -0.078763
# year                -0.316534  1.000000   -0.003825      0.033532 -0.108644
# popularity           0.050617 -0.003825    1.000000     -0.003546 -0.014021
# danceability        -0.060057  0.033532   -0.003546      1.000000 -0.104038
# energy              -0.078763 -0.108644   -0.014021     -0.104038  1.000000
# key                 -0.002560  0.007380    0.014823      0.032731 -0.003446
# loudness            -0.079912  0.017479    0.030632     -0.033315  0.651016
# mode                -0.003848 -0.007358   -0.021353     -0.067528 -0.040651
# speechiness          0.066998  0.001111    0.021162      0.145590 -0.057018
# acousticness         0.010923  0.033809    0.024619     -0.065429 -0.445469
# instrumentalness    -0.004208 -0.050265   -0.048059      0.023207  0.037861
# ...

# %%
### Heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='viridis')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Insight :
# 1. Variabel year dan duration (ms) berkorelasi negatif cenderung kuat (-0.32), yang artinya semakin tinggi atau besar tahunnya semakin pendek durasinya (ms) dan sebaliknya
# 2. Variabel accousticness memiliki korelasi negatif kuat (-0.45) dengan variabel energy, yang artinya semakin accoustic lagunya maka semakin rendah energynya dan sebaliknya
# 3. Variable danceability memiliki korelasi positif kuat (0.40) dengan variabel valence, yang berarti semakin tinggi danceability maka semakin besar valence
# 4. Variabel loudness dan variabel energy memiliki korelasi positif yang sangat kuat (0.65) yang artinya semakin tinggi loudness maka semakin besar energy

# %%
## Line chart with fills
data_yearly = data_year.groupby('year').count()
data_yearly

plt.figure(figsize=(10,8))
plt.style.use('dark_background')
sns.lineplot(data=data_yearly, x='year', y='song', color='blue', marker = 'o')

# setting background
plt.gca().set_facecolor('darkgrey')

plt.title('Total Songs by Years')
plt.xlabel('Year')
plt.ylabel('Song', fontweight='bold')
plt.grid(True)

# %%
### Menambahkan fills dibawah line chart
plt.figure(figsize=(10,8))
plt.style.use('dark_background')
sns.lineplot(data=data_yearly, x='year', y='song', color='blue', marker='o', linestyle ="--")

# setting background
plt.gca().set_facecolor('darkgrey')
plt.fill_between(data_yearly.index, data_yearly['song'], color='red', alpha=0.2)

plt.title('Total Songs by Years')
plt.xlabel('Year')
plt.ylabel('Song', fontweight='bold')
plt.grid(True)

# %%
### Menambahkan Label pada setiap titik
plt.figure(figsize=(10,8))
plt.style.use('dark_background')
sns.lineplot(data=data_yearly, x='year', y='song', color='blue', marker='o')

# setting background
plt.gca().set_facecolor('darkgrey')
plt.fill_between(data_yearly.index, data_yearly['song'], color='red', alpha=0.2)

# menambahkan angka pada setiap titik
for x,y in zip(data_yearly.index, data_yearly['song']):
    plt.text(x, y, str(y), ha='center', va='bottom', color='yellow')


plt.title('Total Songs by Years')
plt.xlabel('Year')
plt.ylabel('Song', fontweight='bold')
plt.grid(True)

# %%
### Advanced Bar Chart
data_genre = data.groupby('genre', as_index=False).count().sort_values(by='song', ascending=False)
data_genre_top10 = data_genre.head(10)

plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(10,8))
barplot = sns.barplot(data=data_genre_top10, x='genre', y='song', palette='crest')

## Tambahkan label di setiap bar chart
for index, value in enumerate(data_genre_top10['song']):
  plt.text(index, value, str(value), ha='center', va='bottom', fontsize=11, color='black')
plt.title('Top 10 Song by Genre')
plt.xlabel('Genre')
plt.xticks(rotation=90)


sns.despine()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-85-01894a1d29f0>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(data=data_genre_top10, x='genre', y='song', palette='crest')

# %%
# Data Churn
data_churn = pd.read_csv('Telco_customer_churn.csv')
data_churn
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
## Churn reasons (bar chart)
churn_reason = data_churn['Churn Reason'].value_counts().sort_values(ascending=False)
churn_reason
# Out:
# Churn Reason
# Attitude of support person                   192
# Competitor offered higher download speeds    189
# Competitor offered more data                 162
# Don't know                                   154
# Competitor made better offer                 140
# Attitude of service provider                 135
# Competitor had better devices                130
# Network reliability                          103
# Product dissatisfaction                      102
# Price too high                                98
# Service dissatisfaction                       89
# Lack of self-service on Website               88
# Extra data charges                            57
# Moved                                         53
# Lack of affordable download/upload speed      44
# Limited range of services                     44
# Long distance charges                         44
# Poor expertise of phone support               20
# Poor expertise of online support              19
# ...

# %%
churn_reason = churn_reason.reset_index()
churn_reason
# Out:
#                                  Churn Reason  count
# 0                  Attitude of support person    192
# 1   Competitor offered higher download speeds    189
# 2                Competitor offered more data    162
# 3                                  Don't know    154
# 4                Competitor made better offer    140
# 5                Attitude of service provider    135
# 6               Competitor had better devices    130
# 7                         Network reliability    103
# 8                     Product dissatisfaction    102
# 9                              Price too high     98
# 10                    Service dissatisfaction     89
# 11            Lack of self-service on Website     88
# 12                         Extra data charges     57
# 13                                      Moved     53
# 14   Lack of affordable download/upload speed     44
# 15                  Limited range of services     44
# 16                      Long distance charges     44
# ...

# %%
plt.figure(figsize=(10,8))
plt.style.use('default')
sns.barplot(data=churn_reason, x='Churn Reason', y='count', palette='crest')
sns.set_context('notebook')

## Set titles and labels
plt.title('Churn Reasons', fontweight='bold')
plt.suptitle('Churn Analysis', fontweight='bold')
plt.xlabel('Reason')
plt.ylabel('Count')
plt.xticks(rotation=90, horizontalalignment='right')
plt.gca().set_facecolor('grey')
# Out:
# <ipython-input-101-648645f54a39>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=churn_reason, x='Churn Reason', y='count', palette='crest')

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
### Multiple bar chart
internet_service = data_churn.groupby(['Internet Service', 'Churn Label']).size().reset_index(name='Jumlah')
internet_service
# Out:
#   Internet Service Churn Label  Jumlah
# 0              DSL          No    1962
# 1              DSL         Yes     459
# 2      Fiber optic          No    1799
# 3      Fiber optic         Yes    1297
# 4               No          No    1413
# 5               No         Yes     113

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(data = internet_service, x='Internet Service', y='Jumlah', hue='Churn Label', palette = {'No':'Red', 'Yes':'Green'})

# Menambahkan label di setiap bar
for s in ax.containers:
  ax.bar_label(s, fmt='%.0f')

plt.title('Comparison Internet Service and Churn')
plt.xlabel('Internet Service')
plt.ylabel('Jumlah')
plt.legend(title='Churn Label')
plt.xticks(rotation=90)
plt.show()
