# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ---
# Outline:
# 1. Data Understanding
#
#   1.1. Preliminary
#     - Statistical Summary & Quartiles
#     - Distribution Forms
#     - Numerical Columns
#     - Categorical Columns
#
#   1.2. Feature Engineering / Data Cleaning / Data Manipulation for EDA
#     - Handling Duplicated
#     - Outlier Handling
#     - Missing value checking and handling
#     - Encoding
#     - Feature Scaling
#
# 2. Reading and Extracting Data
#   - Univariate Analysis
#   - Multivariate Analysis

# %% [markdown]
# ## Statistical Summary
#
# ---
# - The first thing to do is to look at the statistical summary of each column
# - Objectives: to understand how the values are distributed for each column
#   - What are the min/max values? Do they make sense?
#   - Is the distribution skewed or symmetric?
#     - Median!= Mean => Skewed (Not symmetric)
#     - Median ~ Mean => Symmetric
#   - How is each value's frequency? (for categorical column)
# - Best practice: separate your column between numeric and categoric
#
# ##Review: Quartiles
#
# ---
# Q1, Q2, Q3 values are important statistics of sorted data
# ![Screenshot 2025-05-04 at 10.30.17 AM.png](data:image/png;base64,...)

# %% [markdown]
# ###Distributions Form
# There are three forms of distributions
#
# ![Screenshot 2025-05-04 at 10.28.05 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Numerical Columns
# Tips:
# - Checking minimum and maximum value, is it makes sense for each column? here you need business understanding in each columns
# - checking mean, median(Q2 / 50%) with related understanding in distributions forms
#
# ![Screenshot 2025-05-04 at 10.36.26 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Categorical columns
# - Checking for top (mode) value in each categorical columns
# - checking for unique value in each columns
# - count as rows
# - freq related with top value
#
# for categorical columns, the method will output
# - the number of unique / distinct categories within the column
# - the information about the most frequent category in the columns
#
# ![Screenshot 2025-05-04 at 10.40.57 AM.png](data:image/png;base64,...)

# %% [markdown]
# https://drive.google.com/drive/folders/1US5Sagslbyz-kYtAuLswHWT_gRqZgIf9?usp=sharing

# %% [markdown]
# ##Duplicate Handling
#
# check perecentage duplicate if value is 1 = no duplicate
#
# if value is != 1 has duplicate

# %% [markdown]
# ## Outlier Handling
#
# is value make sense in each column? if yes no handling
# if not handling it
#
# dilihat bentuk boxplotnya apakah tipis atau tidak, jika masih berisi kemungkinan masih normal, dilihat lagi outlier karena discreet atau bukan

# %% [markdown]
# ## Missing value handling
# checking % missing feature if >20% drop columns in dataframe (but need to consult with supervisor)
#
# if <20% handle if numerical use median, if object/categorical use mode.
#
# jika data time series, gunakan interpolasi.

# %% [markdown]
# ## Encoding
# (mengubah nilai category menjadi numerik) sifatnya opsional
#
# need to be make sense to encode.
#
# has ordinal category (hirarki level)
# has nominal category (kardinalitas if no then OHE. if yes mean encoding.

# %% [markdown]
# ## Feature scaling
# (opsional)
# nilai numerik ditranformasi menjadi lebih kecil contoh gaji 5jt hingga 100jt
# pakai standar scaller jika ingin sifatnya sama dgn std deviasi. pakai min max scaller jika tidak.

# %% [markdown]
# ## Univariate Analysis - Boxplot
#
# masih aman walau ada outlier selama boxnya tidak tipis dan tidak jauh outliernya.

# %% [markdown]
# ##Univariate Analysis - Inspect distribution in numerical
#
# melihat distribusi dari histogram
#
# categorical pakai barplot saja

# %% [markdown]
# ## Data manipulation
#
# https://drive.google.com/drive/folders/1ckaF1pOpuYeu0m7rYt3Ef_S0J36JSWwY?usp=sharing
#
# ## Data Cleaning
#
# https://drive.google.com/drive/folders/1US5Sagslbyz-kYtAuLswHWT_gRqZgIf9?usp=sharing

# %% [markdown]
# ## HO!

# %% [markdown]
# https://colab.research.google.com/drive/1F2iq8lbFs06oLjHxe9VjVVrum3wkprH-?usp=sharing
